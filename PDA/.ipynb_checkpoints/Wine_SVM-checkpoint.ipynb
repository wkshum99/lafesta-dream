# %%
import csv
import pandas as pd
import matplotlib.cm as cm
from sklearn import decomposition
% matplotlib inline
#import itertools

# %%
#indata = csv.reader('wine.data')

# %%
#a = []
#for i in itertools.combinations(range(1,14),2):
#    a.append(i)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
def getData(file):
    return pd.read_csv(file, header=None, names=['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines',  'Proline'], index_col=None)
    #result = []
    #lists = [line.strip().split(",") for line in open('wine.data', 'r').readlines()]
    #return [list( l[1:14]) for l in lists], [l[0] for l in lists]
    #with open(file) as f:
    #    csvreader = csv.reader(f)
    #    for row in csvreader:
    #        lists.append(row)

    #return [l[1:14] for l in lists], [l[0] for l in lists]

# %%
df = getData('wine.data')
xaxis1 = []; yaxis1 = []
xaxis2 = []; yaxis2 = []
xaxis3 = []; yaxis3 = []

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
type1 = ax.scatter(df[df['Class'] == 1][[1]], df[df['Class'] == 1][[2]], s=50, c='white')
type2 = ax.scatter(df[df['Class'] == 2][[1]], df[df['Class'] == 2][[2]], s=50, c='red')
type3 = ax.scatter(df[df['Class'] == 3][[1]], df[df['Class'] == 3][[2]], s=50, c='darkred')
ax.set_title('Wine Features', fontsize=14)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.legend([type1, type2, type3], ["Class 1", "Class 2", "Class 3"], loc=1)
ax.grid(True,linestyle='-',color='0.80')

plt.show()

# %%
x = df[range(2,5)]
y = df[[0]]

# %%
pca = mlpy.PCA()
pca.learn(x) 
z = pca.transform(x, k=2)
 
fig1 = plt.figure(1)
title = plt.title("PCA on wine dataset")
plot = plt.scatter(z[:, 0], z[:, 1], c=y, s=90, cmap=cm.Reds)
labx = plt.xlabel("First component")
laby = plt.ylabel("Second component")
plt.show()

svm = mlpy.LibSvm(kernel_type='linear') 
svm.learn(z, y) 

xmin, xmax = z[:,0].min()-0.1, z[:,0].max()+0.1
ymin, ymax = z[:,1].min()-0.1, z[:,1].max()+0.1
xx, yy = np.meshgrid(np.arange(xmin, xmax, 0.01),
         np.arange(ymin, ymax, 0.01))
grid = np.c_[xx.ravel(), yy.ravel()]

result = svm.pred(grid)

fig2 = plt.figure(2)
plot1 = plt.pcolormesh(xx, yy, result.reshape(xx.shape), cmap=cm.Greys_r)
plot2 = plt.scatter(z[:, 0], z[:, 1], c=y, s=90, cmap=cm.Reds)
labx = plt.xlabel("First component")
laby = plt.ylabel("Second component")
limx = plt.xlim(xmin, xmax)
limy = plt.ylim(ymin, ymax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-f43c6661fe8d> in <module>()
#       1 import numpy as np
# ----> 2 import mlpy
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.cm as cm
#       5
#
# C:\Users\ivy\Anaconda\lib\site-packages\mlpy\__init__.py in <module>()
#      16     from .lcs import *
#      17 else:
# ---> 18     import gsl
#      19     from libsvm import *
#      20     from liblinear import *
#
# ImportError: DLL load failed: %1 is not a valid Win32 application.

# %%
mlpy.
